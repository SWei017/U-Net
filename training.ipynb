# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change current directory to model folder
# %cd ./drive/My\ Drive/Colab\ Notebooks/UNet
# Out:
# /content/drive/My Drive/Colab Notebooks/UNet

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/UNet

# %%
import torch

torch.cuda.empty_cache()

# %%
# !python3 train.py --model UNet --batch_size 32 --filename_suffix '(Adamax 12 May)' --lr 0.001 --ricap_probability 0 --optimizer Adamax
# Out:
# Loading model UNet
# Previous model detected

# %%
import os

os.path.isdir('/content/drive/My Drive/Colab Notebooks/Training Images/overlapped')
# Out:
# True
